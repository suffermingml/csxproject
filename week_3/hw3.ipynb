# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

plt.style.use('ggplot')
# %matplotlib inline

# %%
df=pd.read_csv("Orders.csv",encoding = 'utf8')
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#            DateId  MemberId  \
# 0        20150703   1388133
# 1        20150703   1388133
# 2        20150703   1388133
# 3        20150703   1388133
# 4        20150703    365787
# 5        20150703    365787
# 6        20150703    365787
# 7        20150703    365787
# 8        20150703   1388127
# 9        20150703   1388127
# 10       20150703   1388127
# 11       20150703   1388127
# 12       20150703   1388127
# 13       20150703   1387512
# 14       20150703   1387512
# 15       20150703   1387512
# 16       20150703   1387512
# 17       20150703   1387512
# 18       20150703   1387512
# 19       20150703   1230537
# 20       20150703   1230537
# 21       20150703   1230537
# 22       20150703   1230537
# 23       20150703   1230537
# 24       20150703   1230537
# 25       20150703   1230537
# 26       20150703   1230537
# 27       20150703   1230537
# 28       20150703   1230537
# 29       20150703   1230537
# ...           ...       ...
# 5495246  20170329   4902444
# ...

# %%
dfm=pd.read_csv("Member.csv")
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5495276 entries, 0 to 5495275
# Data columns (total 28 columns):
# DateId                         int64
# MemberId                       int64
# OrderGroupCode                 object
# TrackSourceTypeDef             object
# TrackDeviceTypeDef             object
# PayProfileTypeDef              object
# SalesOrderSlaveId              int64
# SalePageId                     int64
# IsMajor                        bool
# IsGift                         bool
# IsSalePageGift                 bool
# Quantity                       int64
# UnitPrice                      float64
# PromotionDiscount              float64
# ECouponId                      int64
# ECouponDiscount                float64
# SalesOrderSlaveTotalPayment    float64
# SalesOrderSlaveDateTime        object
# SalesOrderReceiverId           int64
# City                           object
# District                       object
# ZipCode                        float64
# ...

# %%
dff=df[["MemberId","Quantity","UnitPrice","City"]]
dff
# Out:
#          MemberId  Quantity  UnitPrice City
# 0         1388133         1      350.0  嘉義縣
# 1         1388133         1      199.0  嘉義縣
# 2         1388133         1      199.0  嘉義縣
# 3         1388133         1      225.0  嘉義縣
# 4          365787         1      100.0  桃園市
# 5          365787         1      188.0  桃園市
# 6          365787         1      199.0  桃園市
# 7          365787         1       99.0  桃園市
# 8         1388127         1      250.0  台南市
# 9         1388127         1      250.0  台南市
# 10        1388127         1      199.0  台南市
# 11        1388127         1      249.0  台南市
# 12        1388127         1      150.0  台南市
# 13        1387512         1      299.0  新北市
# 14        1387512         1      199.0  新北市
# 15        1387512         1      299.0  新北市
# 16        1387512         1      199.0  新北市
# 17        1387512         1      199.0  新北市
# 18        1387512         1      150.0  新北市
# 19        1230537         1      399.0  新竹市
# ...

# %%
dff["amount"]=df["Quantity"]*df["UnitPrice"]
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dff
# Out:
#          MemberId  Quantity  UnitPrice City  amount
# 0         1388133         1      350.0  嘉義縣   350.0
# 1         1388133         1      199.0  嘉義縣   199.0
# 2         1388133         1      199.0  嘉義縣   199.0
# 3         1388133         1      225.0  嘉義縣   225.0
# 4          365787         1      100.0  桃園市   100.0
# 5          365787         1      188.0  桃園市   188.0
# 6          365787         1      199.0  桃園市   199.0
# 7          365787         1       99.0  桃園市    99.0
# 8         1388127         1      250.0  台南市   250.0
# 9         1388127         1      250.0  台南市   250.0
# 10        1388127         1      199.0  台南市   199.0
# 11        1388127         1      249.0  台南市   249.0
# 12        1388127         1      150.0  台南市   150.0
# 13        1387512         1      299.0  新北市   299.0
# 14        1387512         1      199.0  新北市   199.0
# 15        1387512         1      299.0  新北市   299.0
# 16        1387512         1      199.0  新北市   199.0
# ...

# %%
kkk=dff[["MemberId","City","amount"]]

# %%
kkk
# Out:
#          MemberId City  amount
# 0         1388133  嘉義縣   350.0
# 1         1388133  嘉義縣   199.0
# 2         1388133  嘉義縣   199.0
# 3         1388133  嘉義縣   225.0
# 4          365787  桃園市   100.0
# 5          365787  桃園市   188.0
# 6          365787  桃園市   199.0
# 7          365787  桃園市    99.0
# 8         1388127  台南市   250.0
# 9         1388127  台南市   250.0
# 10        1388127  台南市   199.0
# 11        1388127  台南市   249.0
# 12        1388127  台南市   150.0
# 13        1387512  新北市   299.0
# 14        1387512  新北市   199.0
# 15        1387512  新北市   299.0
# 16        1387512  新北市   199.0
# 17        1387512  新北市   199.0
# 18        1387512  新北市   150.0
# 19        1230537  新竹市   399.0
# 20        1230537  新竹市   250.0
# 21        1230537  新竹市   320.0
# 22        1230537  新竹市   199.0
# 23        1230537  新竹市   249.0
# 24        1230537  新竹市   299.0
# 25        1230537  新竹市   599.0
# 26        1230537  新竹市   299.0
# 27        1230537  新竹市   320.0
# 28        1230537  新竹市   225.0
# ...

# %%
k2=kkk.groupby(by=['MemberId'])["amount"].mean()
a1=k2[k2<100].count()
a2=k2[k2<200].count()-a1
a3=k2[k2<300].count()-a2-a1
a4=k2[k2<400].count()-a3-a2-a1
a5=k2[k2<500].count()-a4-a3-a2-a1
a6=k2[k2<600].count()-a5-a4-a3-a2-a1
a7=k2[k2<700].count()-a6-a5-a4-a3-a2-a1
a8=k2[k2<800].count()-a7-a6-a5-a4-a3-a2-a1
a9=k2[k2<900].count()-a8-a7-a6-a5-a4-a3-a2-a1
a10=k2[k2<1000].count()-a9-a8-a7-a6-a5-a4-a3-a2-a1
a11=k2[k2>1000].count()
aaa={
    "index":[
    "100","200",
    "300",
    "400",
    "500",
    "600",
    "700",
    "800",
    "900",
    "1000",
    ">1000"],
    "values":[
        a1,a2,a3,a4,a5,a6,a7,a8,a9,a10,a11
    ]
    
    
}
aa=pd.DataFrame(aaa)

# %%
aa
# Out:
#     index  values
# 0     100    1475
# 1     200   73080
# 2     300  330963
# 3     400  121081
# 4     500   23957
# 5     600    7419
# 6     700    2522
# 7     800    1506
# 8     900     399
# 9    1000     513
# 10  >1000     529

# %%
plt.plot(aa["index"],aa["values"])
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['STXihei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
k3=kkk.groupby(by=["City"])["amount"].mean()
k33=k3.iloc[21:]
k33
# Out:
# City
# 南投縣    266.712677
# 台中市    266.603535
# 台北市    270.326995
# 台南市    264.283945
# 台東市    263.394737
# 台東縣    265.172298
# 嘉義市    267.547356
# 嘉義縣    263.428567
# 基隆市    269.511685
# 宜蘭縣    268.306231
# 屏東市    267.247382
# 屏東縣    261.096503
# 彰化縣    264.801439
# 新北市    270.295276
# 新竹市    269.120484
# 新竹縣    271.218047
# 桃園市    269.913341
# 桃園縣    290.369565
# 澎湖縣    266.115081
# 花蓮縣    265.247459
# 苗栗縣    266.880383
# 雲林縣    264.353312
# 高雄市    263.446110
# Name: amount, dtype: float64

# %%
k33.plot.bar()
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['STXihei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
k4=kkk.groupby(by=["City"])["amount"].sum()
k44=k4.iloc[21:]

# %%
k44
# Out:
# City
# 南投縣     19496430.0
# 台中市    213037819.0
# 台北市    187562871.0
# 台南市    105399080.0
# 台東市       110099.0
# 台東縣      9024874.0
# 嘉義市     14443544.0
# 嘉義縣     17513258.0
# 基隆市     23664743.0
# 宜蘭縣     22838763.0
# 屏東市       204177.0
# 屏東縣     31952990.0
# 彰化縣     52145229.0
# 新北市    317389362.0
# 新竹市     39127158.0
# 新竹縣     34493240.0
# 桃園市    158421317.0
# 桃園縣        26714.0
# 澎湖縣      5228363.0
# 花蓮縣     17954070.0
# 苗栗縣     28303999.0
# 雲林縣     22750246.0
# 高雄市    149912955.0
# Name: amount, dtype: float64

# %%
k44.plot.bar()
# Out:
# /Users/apple/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['STXihei'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
